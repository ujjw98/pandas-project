# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\Owner\Desktop\python\data sets\project 1\Ecommerce Purchases")

# %% [markdown]
# #displaying top 5 entries of the data

# %%
data["Purchase Price"]
# Out:
# 0       98.14
# 1       70.73
# 2        0.95
# 3       78.04
# 4       77.82
#         ...
# 9995    82.21
# 9996    25.63
# 9997    83.98
# 9998    38.84
# 9999    67.59
# Name: Purchase Price, Length: 10000, dtype: float64

# %% [markdown]
# #displaying lasst 10 entries of the dataset

# %%
df=data.sort_values(by = 'Purchase Price' , ascending = False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 2092 to 5487
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %% [markdown]
# #displaying datatype of each column

# %%
df.dtypes
# Out:
# Address              object
# Lot                  object
# AM or PM             object
# Browser Info         object
# Company              object
# Credit Card           int64
# CC Exp Date          object
# CC Security Code      int64
# CC Provider          object
# Email                object
# Job                  object
# IP Address           object
# Language             object
# Purchase Price      float64
# dtype: object

# %% [markdown]
# check null values in the data set

# %%
df.isnull().sum()
# Out:
# Address             0
# Lot                 0
# AM or PM            0
# Browser Info        0
# Company             0
# Credit Card         0
# CC Exp Date         0
# CC Security Code    0
# CC Provider         0
# Email               0
# Job                 0
# IP Address          0
# Language            0
# Purchase Price      0
# dtype: int64

# %%
df.Lot.isnull()
# Out:
# 2092    False
# 7807    False
# 9856    False
# 7604    False
# 3844    False
#         ...
# 2783    False
# 8656    False
# 6863    False
# 2876    False
# 5487    False
# Name: Lot, Length: 10000, dtype: bool

# %%
data['Credit Card'].isnull().sum()
# Out:
# 0

# %% [markdown]
# how many rows and columns are there in our data frame

# %%
df.shape
# Out:
# (10000, 14)

# %%
data.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
len(data)
# Out:
# 10000

# %%
len(data.columns)
# Out:
# 14

# %% [markdown]
# dispaly highest and lowest purchase price

# %%
df1 = data['Purchase Price']

# %%
# data  = data.sort_values(by = Purchase Price ,  ascending = False)
# print(data.head())

a=df1.max()
a
# Out:
# 99.99

# %%
b=df1.min()
b
# Out:
# 0.0

# %%
df1
# Out:
# 0       98.14
# 1       70.73
# 2        0.95
# 3       78.04
# 4       77.82
#         ...
# 9995    82.21
# 9996    25.63
# 9997    83.98
# 9998    38.84
# 9999    67.59
# Name: Purchase Price, Length: 10000, dtype: float64

# %%
pip install xarray
# Out:
# ...
#                                               0.0/1.0 MB ? eta -:--:--
#      --                                       0.1/1.0 MB 1.7 MB/s eta 0:00:01
#      ------                                   0.2/1.0 MB 2.0 MB/s eta 0:00:01
#      -------------                            0.3/1.0 MB 2.5 MB/s eta 0:00:01
#      ----------------------                   0.6/1.0 MB 3.3 MB/s eta 0:00:01
#      ------------------------------           0.8/1.0 MB 3.4 MB/s eta 0:00:01
#      ---------------------------------------- 1.0/1.0 MB 3.8 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import xarray as xr

# %%
dataset = xr.Dataset.from_dataframe(df)

# %%
dataset
# Out:
# <xarray.Dataset>
# Dimensions:           (index: 10000)
# Coordinates:
#   * index             (index) int64 2092 7807 9856 7604 ... 8656 6863 2876 5487
# Data variables: (12/14)
#     Address           (index) object '63773 Shelton Greens\nAshleyton, MA 004...
#     Lot               (index) object '56 lu' '64 Nf' '73 IW' ... '39 GT' '93 OH'
#     AM or PM          (index) object 'AM' 'AM' 'PM' 'PM' ... 'PM' 'AM' 'AM' 'PM'
#     Browser Info      (index) object 'Mozilla/5.0 (X11; Linux x86_64) AppleWe...
#     Company           (index) object 'Pitts Group' ... 'Flynn and Sons'
#     Credit Card       (index) int64 4292741269160 ... 30469912089738
#     ...                ...
#     CC Provider       (index) object 'Maestro' 'VISA 16 digit' ... 'Discover'
#     Email             (index) object 'heatherwoodard@lloyd.com' ... 'mjohnson...
#     Job               (index) object 'Surveyor, hydrographic' ... 'Stage mana...
# ...

# %%
u=dataset["Purchase Price"]
u
# Out:
# <xarray.DataArray 'Purchase Price' (index: 10000)>
# array([9.999e+01, 9.999e+01, 9.997e+01, ..., 1.000e-02, 0.000e+00,
#        0.000e+00])
# Coordinates:
#   * index    (index) int64 2092 7807 9856 7604 3844 ... 2783 8656 6863 2876 5487

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=u
y=np.arange(1,10001)

# %%
x.size
# Out:
# 10000

# %%
plt.plot(x,y)

# %%
data.head(2)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
#
#    CC Security Code   CC Provider               Email  \
# 0               900  JCB 16 digit   pdunlap@yahoo.com
# 1               561    Mastercard  anthony41@reed.com
#
#                                       Job       IP Address Language  \
# 0  Scientist, product/process development  149.146.147.205       el
# 1                       Drilling engineer     15.160.41.51       fr
#
# ...

# %% [markdown]
# find the average purchase price

# %%
df['Purchase Price'].mean()
# Out:
# 50.347302

# %% [markdown]
# how many people has french as their language

# %%
df1 = df
df1.head(2)
# Out:
#                                         Address    Lot AM or PM  \
# 2092  63773 Shelton Greens\nAshleyton, MA 00493  56 lu       AM
# 7807      PSC 6177, Box 1004\nAPO AA 57143-1269  64 Nf       AM
#
#                                            Browser Info  \
# 2092  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 7807  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_5_4)...
#
#                         Company     Credit Card CC Exp Date  CC Security Code  \
# 2092                Pitts Group   4292741269160       06/18               824
# 7807  Porter, Johnson and Pratt  30109394842259       11/25               918
#
#         CC Provider                     Email                     Job  \
# 2092        Maestro  heatherwoodard@lloyd.com  Surveyor, hydrographic
# 7807  VISA 16 digit         kelli72@gmail.com     Surveyor, insurance
#
#            IP Address Language  Purchase Price
# 2092  172.197.216.229       el           99.99
# 7807     89.51.92.242       de           99.99

# %%
len(df1[df1['Language'] == 'fr'])
# Out:
# 1097

# %%
df1[df1['Language'] == 'fr'].count()
# Out:
# Address             1097
# Lot                 1097
# AM or PM            1097
# Browser Info        1097
# Company             1097
# Credit Card         1097
# CC Exp Date         1097
# CC Security Code    1097
# CC Provider         1097
# Email               1097
# Job                 1097
# IP Address          1097
# Language            1097
# Purchase Price      1097
# dtype: int64

# %%
df.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
df_job  = df[df['Job'] == 'Site engineer']
len(df_job)
# Out:
# 13

# %%
df_job1 = df[df['Job'].str.contains('engineer' , case = False)]
df_job1
# Out:
#                                                 Address    Lot AM or PM  \
# 9856  058 Miranda Locks Suite 792\nPort Davidstad, P...  73 IW       PM
# 6441     3307 Franklin Garden\nPort Scottland, UT 79128  68 ie       AM
# 9934     52276 Smith Cliffs\nLake Vanessaview, AL 91791  40 nG       AM
# 5473  63375 Wall Glens\nSouth Rebeccaland, UT 37955-...  32 qB       PM
# 2526    71629 Cristian Squares\nLake Benjamin, CO 33249  86 Tv       PM
# ...                                                 ...    ...      ...
# 3798  8461 Morales Way Apt. 798\nHernandezside, WA 6...  79 aL       PM
# 1009          6400 Smith Key\nWest Jamesmouth, DC 89748  06 tQ       PM
# 7207  9087 Sandoval Summit Suite 016\nWilsonfurt, OR...  83 jY       AM
# 9704           603 Tran Alley\nDuffyview, MD 99742-9731  05 hI       PM
# 6647         86103 Ricky Manor\nNunezton, VI 03206-5280  69 MM       PM
#
#                                            Browser Info  \
# ...

# %%
len(df_job1)
# Out:
# 984

# %% [markdown]
# find email of the person with the following ip address

# %%
ipadd =  df
ipadd[ipadd['IP Address'] == '132.207.160.22']['Email']
# Out:
# 2    amymiller@morales-harrison.com
# Name: Email, dtype: object

# %% [markdown]
# how many people has master card as their credit card provider and made a purchase of above 50$

# %%
card = df
card.head(2)
# Out:
#                                         Address    Lot AM or PM  \
# 2092  63773 Shelton Greens\nAshleyton, MA 00493  56 lu       AM
# 7807      PSC 6177, Box 1004\nAPO AA 57143-1269  64 Nf       AM
#
#                                            Browser Info  \
# 2092  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 7807  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_5_4)...
#
#                         Company     Credit Card CC Exp Date  CC Security Code  \
# 2092                Pitts Group   4292741269160       06/18               824
# 7807  Porter, Johnson and Pratt  30109394842259       11/25               918
#
#         CC Provider                     Email                     Job  \
# 2092        Maestro  heatherwoodard@lloyd.com  Surveyor, hydrographic
# 7807  VISA 16 digit         kelli72@gmail.com     Surveyor, insurance
#
#            IP Address Language  Purchase Price
# 2092  172.197.216.229       el           99.99
# 7807     89.51.92.242       de           99.99

# %%
 count_card = card[(card['CC Provider'] == 'Mastercard') & (card['Purchase Price'] > 50)]
count_card
# Out:
#                                                 Address    Lot AM or PM  \
# 3844  27148 Kathy Cliff Apt. 400\nEast Jillton, TX 5...  37 ou       PM
# 6263              PSC 1273, Box 3037\nAPO AA 11854-3422  93 HJ       PM
# 8023                   Unit 6888 Box 8570\nDPO AP 38570  83 ir       PM
# 177   054 Hatfield Prairie Apt. 730\nClarkmouth, DE ...  33 IK       PM
# 2526    71629 Cristian Squares\nLake Benjamin, CO 33249  86 Tv       PM
# ...                                                 ...    ...      ...
# 3268            483 Garcia Inlet\nMedinaburgh, WV 60489  20 tt       AM
# 2214  66787 Spencer Plains Suite 325\nArnoldton, LA ...  34 Jw       PM
# 2462  9675 Christopher Lodge Apt. 825\nEast Veronica...  65 YC       AM
# 9917  17954 Ramirez Spurs Apt. 208\nKellyshire, OR 3...  21 yk       PM
# 9364              PSC 2544, Box 2138\nAPO AA 76235-9190  49 ju       AM
#
#                                            Browser Info  \
# ...

# %%
len(count_card)
# Out:
# 405

# %% [markdown]
# find the email of the person with the following credit card number '869955969823264'

# %%
email_cardno = df

# %%
email_cardno[(email_cardno['CC Provider'] == 'Mastercard') & (email_cardno['Credit Card'] == 869955969823264)]['Email']
# email_cardno
# Out:
# 9917    duaneross@johnson-gonzalez.com
# Name: Email, dtype: object

# %% [markdown]
# how many person purchasing during AM and how many during PM

# %%
df.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
ampm = df['AM or PM'].value_counts()
ampm
# Out:
# AM or PM
# PM    5068
# AM    4932
# Name: count, dtype: int64

# %% [markdown]
# how many people have credit cards that expires in 2020

# %%
exp_date = data

# %%
exp_date['CC Exp Date']
# Out:
# 0       02/20
# 1       11/18
# 2       08/19
# 3       02/24
# 4       10/25
#         ...
# 9995    03/22
# 9996    07/25
# 9997    05/21
# 9998    11/17
# 9999    02/19
# Name: CC Exp Date, Length: 10000, dtype: object

# %% [markdown]
# top five most popular emial provider

# %%
email = data
email['E
