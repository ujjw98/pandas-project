# %% [markdown]
# data set of the san francisco city emplyee saleries

# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\Owner\Desktop\python\data sets\project 2\Salaries.csv")
data.head()
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_10936\3591118739.py:1: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(r"C:\Users\Owner\Desktop\python\data sets\project 2\Salaries.csv")
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# ...

# %%
data.describe()
# Out:
#                   Id       TotalPay  TotalPayBenefits           Year  Notes
# count  148654.000000  148654.000000     148654.000000  148654.000000    0.0
# mean    74327.500000   74768.321972      93692.554811    2012.522643    NaN
# std     42912.857795   50517.005274      62793.533483       1.117538    NaN
# min         1.000000    -618.130000       -618.130000    2011.000000    NaN
# 25%     37164.250000   36168.995000      44065.650000    2012.000000    NaN
# 50%     74327.500000   71426.610000      92404.090000    2013.000000    NaN
# 75%    111490.750000  105839.135000     132876.450000    2014.000000    NaN
# max    148654.000000  567595.430000     567595.430000    2014.000000    NaN

# %%
data.shape
# Out:
# (148654, 13)

# %%
print("number of rows" , data.shape[0])
print("number of columns" , data.shape[1])
# Out:
# number of rows 148654
# number of columns 13

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %% [markdown]
# check null values in the data set

# %%
data.isnull()
# Out:
#            Id  EmployeeName  JobTitle  BasePay  OvertimePay  OtherPay  \
# 0       False         False     False    False        False     False
# 1       False         False     False    False        False     False
# 2       False         False     False    False        False     False
# 3       False         False     False    False        False     False
# 4       False         False     False    False        False     False
# ...       ...           ...       ...      ...          ...       ...
# 148649  False         False     False    False        False     False
# 148650  False         False     False    False        False     False
# 148651  False         False     False    False        False     False
# 148652  False         False     False    False        False     False
# 148653  False         False     False    False        False     False
#
#         Benefits  TotalPay  TotalPayBenefits   Year  Notes  Agency  Status
# ...

# %%
data.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %%
data.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %% [markdown]
# drop id , notes , agency , status column

# %%
df = data
df  = df.drop(['Id' , 'Notes' , 'Status'] , axis = 1)
df.shape
# Out:
# (148654, 10)

# %%
df.head(1)
# Out:
#      EmployeeName                                        JobTitle    BasePay  \
# 0  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
#
#   OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  Year  \
# 0         0.0  400184.25      NaN  567595.43         567595.43  2011
#
#           Agency
# 0  San Francisco

# %% [markdown]
# get overall statics about the data frame

# %%
df.describe(include = 'all')
# Out:
#        EmployeeName          JobTitle   BasePay  OvertimePay  OtherPay  \
# count        148654            148654  148049.0     148654.0  148654.0
# unique       110811              2159  109900.0      66555.0   84968.0
# top       Kevin Lee  Transit Operator       0.0          0.0       0.0
# freq             13              7036     875.0      66103.0   35218.0
# mean            NaN               NaN       NaN          NaN       NaN
# std             NaN               NaN       NaN          NaN       NaN
# min             NaN               NaN       NaN          NaN       NaN
# 25%             NaN               NaN       NaN          NaN       NaN
# 50%             NaN               NaN       NaN          NaN       NaN
# 75%             NaN               NaN       NaN          NaN       NaN
# max             NaN               NaN       NaN          NaN       NaN
#
#         Benefits       TotalPay  TotalPayBenefits           Year  \
# ...

# %% [markdown]
# find occurance of the employee names top 5

# %%
df1 = data
df['EmployeeName'].value_counts().head()
# Out:
# EmployeeName
# Kevin Lee       13
# Richard Lee     11
# Steven Lee      11
# William Wong    11
# Stanley Lee      9
# Name: count, dtype: int64

# %% [markdown]
# find the number of unique job titles

# %%
df2 = data
df2['JobTitle'].nunique()
# Out:
# 2159

# %% [markdown]
# total number of job titles containing captain

# %%
len(df2[df2['JobTitle'].str.contains('CAPTAIN' , case = False)])
# Out:
# 552

# %% [markdown]
# dispaly all employee names from fire department

# %%
data.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
data.head(2)
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2    GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN
# 1  2011    NaN  San Francisco    NaN

# %%
df2[df2['JobTitle'].str.contains('FIRE DEPARTMENT' , case = False)]
# Out:
#             Id          EmployeeName  \
# 4            5       PATRICK GARDNER
# 6            7             ALSON LEE
# 8            9        MICHAEL MORRIS
# 9           10    JOANNE HAYES-WHITE
# 10          11         ARTHUR KENNEY
# ...        ...                   ...
# 32623    32624          JAMES BARDEN
# 36162    36163    Joanne Hayes-White
# 72926    72927  Joanne M Hayes-White
# 102303  102304        Robert E Evans
# 110535  110536  Joanne M Hayes-White
#
#                                                 JobTitle    BasePay  \
# 4           DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)   134401.6
# 6                     BATTALION CHIEF, (FIRE DEPARTMENT)   92492.01
# 8                     BATTALION CHIEF, (FIRE DEPARTMENT)  176932.64
# 9                 CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)   285262.0
# 10      ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)  194999.39
# ...                                                  ...        ...
# ...

# %%
employee_names = df2[df2['JobTitle'].str.contains('FIRE DEPARTMENT' , case = False)]['EmployeeName']

# %%
employee_names.count()
# Out:
# 226

# %%
data.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df2['BasePay']
# Out:
# 0            167411.18
# 1            155966.02
# 2            212739.13
# 3              77916.0
# 4             134401.6
#               ...
# 148649            0.00
# 148650    Not Provided
# 148651    Not Provided
# 148652    Not Provided
# 148653            0.00
# Name: BasePay, Length: 148654, dtype: object

# %%
df2.describe()
# Out:
#                   Id       TotalPay  TotalPayBenefits           Year  Notes
# count  148654.000000  148654.000000     148654.000000  148654.000000    0.0
# mean    74327.500000   74768.321972      93692.554811    2012.522643    NaN
# std     42912.857795   50517.005274      62793.533483       1.117538    NaN
# min         1.000000    -618.130000       -618.130000    2011.000000    NaN
# 25%     37164.250000   36168.995000      44065.650000    2012.000000    NaN
# 50%     74327.500000   71426.610000      92404.090000    2013.000000    NaN
# 75%    111490.750000  105839.135000     132876.450000    2014.000000    NaN
# max    148654.000000  567595.430000     567595.430000    2014.000000    NaN

# %% [markdown]
# replace "not provided" in empoyee name column to NaN

# %%
df2[df2['EmployeeName'].str.contains('Not Provided' , case =  False)]
# Out:
#             Id  EmployeeName                                 JobTitle  \
# 13797    13798  Not Provided  PUBLIC SAFETY COMMUNICATIONS DISPATCHER
# 44151    44152  Not Provided                   Public SafetyComm Disp
# 148646  148647  Not provided                             Not provided
# 148650  148651  Not provided                             Not provided
# 148651  148652  Not provided                             Not provided
# 148652  148653  Not provided                             Not provided
#
#              BasePay   OvertimePay      OtherPay      Benefits   TotalPay  \
# 13797       57963.39      19683.91       4373.86           NaN   82021.16
# 44151       82196.52       25934.2       3752.49       38024.3  111883.21
# 148646  Not Provided  Not Provided  Not Provided  Not Provided       0.00
# 148650  Not Provided  Not Provided  Not Provided  Not Provided       0.00
# 148651  Not Provided  Not Provided  Not Provided  Not Provided       0.00
# ...

# %%
import numpy as np
df2['EmployeeName'] = df2['EmployeeName'].replace('Not provided' , np.nan)

# %%
df2.iloc[148652]
# Out:
# Id                         148653
# EmployeeName                  NaN
# JobTitle             Not provided
# BasePay              Not Provided
# OvertimePay          Not Provided
# OtherPay             Not Provided
# Benefits             Not Provided
# TotalPay                      0.0
# TotalPayBenefits              0.0
# Year                         2014
# Notes                         NaN
# Agency              San Francisco
# Status                        NaN
# Name: 148652, dtype: object

# %% [markdown]
# #drop rows having 5 missing values

# %%
df3 = data
df3.drop(df3[df3.isnull().sum(axis = 1) == 3].index , axis = 0)
# df3
# Out:
#             Id        EmployeeName                      JobTitle    BasePay  \
# 36159    36160      Gary Altenberg  Lieutenant, Fire Suppression  128808.87
# 36160    36161        Gregory Suhr               Chief of Police   302578.0
# 36161    36162          Khoa Trinh   Electronic Maintenance Tech   111921.0
# 36162    36163  Joanne Hayes-White        Chief, Fire Department  296943.01
# 36163    36164   Frederick Binkley     EMT/Paramedic/Firefighter  126863.19
# ...        ...                 ...                           ...        ...
# 148645  148646    Carolyn A Wilson     Human Services Technician       0.00
# 148647  148648      Joann Anderson   Communications Dispatcher 2       0.00
# 148648  148649         Leon Walker                     Custodian       0.00
# 148649  148650       Roy I Tillery                     Custodian       0.00
# 148653  148654           Joe Lopez    Counselor, Log Cabin Ranch       0.00
#
# ...

# %% [markdown]
# find job title of albert pardini

# %%
df2['JobTitle']
# Out:
# 0         GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                        CAPTAIN III (POLICE DEPARTMENT)
# 2                        CAPTAIN III (POLICE DEPARTMENT)
# 3                   WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4           DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#                                ...
# 148649                                         Custodian
# 148650                                      Not provided
# 148651                                      Not provided
# 148652                                      Not provided
# 148653                        Counselor, Log Cabin Ranch
# Name: JobTitle, Length: 148654, dtype: object

# %% [markdown]
# find job title of albert pardini

# %%
df2[df2['EmployeeName'] == 'ALBERT PARDINI']
# Out:
#             Id    EmployeeName  \
# 0            1  ALBERT PARDINI
# 1            2  ALBERT PARDINI
# 2            3  ALBERT PARDINI
# 3            4  ALBERT PARDINI
# 4            5  ALBERT PARDINI
# ...        ...             ...
# 148649  148650  ALBERT PARDINI
# 148650  148651  ALBERT PARDINI
# 148651  148652  ALBERT PARDINI
# 148652  148653  ALBERT PARDINI
# 148653  148654  ALBERT PARDINI
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# 148649                                       Custodian          0.00
# ...

# %%
df2[df2['EmployeeName'] == 'ALBERT PARDINI']['JobTitle']
# Out:
# 0         GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                        CAPTAIN III (POLICE DEPARTMENT)
# 2                        CAPTAIN III (POLICE DEPARTMENT)
# 3                   WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4           DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#                                ...
# 148649                                         Custodian
# 148650                                      Not provided
# 148651                                      Not provided
# 148652                                      Not provided
# 148653                        Counselor, Log Cabin Ranch
# Name: JobTitle, Length: 148654, dtype: object

# %% [markdown]
# how much ablert paradini make including benifits

# %%
df2.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df2[['BasePay' ,  'Benefits'] == '']
# Out:
#              BasePay      Benefits
# 0          167411.18           NaN
# 1          155966.02           NaN
# 2          212739.13           NaN
# 3            77916.0           NaN
# 4           134401.6           NaN
# ...              ...           ...
# 148649          0.00          0.00
# 148650  Not Provided  Not Provided
# 148651  Not Provided  Not Provided
# 148652  Not Provided  Not Provided
# 148653          0.00          0.00
#
# [148654 rows x 2 columns]

# %%
df2[df2['EmployeeName'] == 'ALBERT PARDINI']['TotalPayBenefits']
# Out:
# 0         567595.43
# 1         538909.28
# 2         335279.91
# 3         332343.61
# 4         326373.19
#             ...
# 148649         0.00
# 148650         0.00
# 148651         0.00
# 148652         0.00
# 148653      -618.13
# Name: TotalPayBenefits, Length: 148654, dtype: float64

# %% [markdown]
# dispaly name of the person having highest base pay

# %%
df2.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
non_numeric_values = df2[~df2['BasePay'].apply(lambda x: isinstance(x, (int, float)))]
print(non_numeric_values['BasePay'].unique())
# Out:
# ['60618.25' '68712.00' '68448.94' ... '6.04' '15.50' 'Not Provided']

# %%
import numpy as np

df2['BasePay'] = pd.to_numeric(df2['BasePay'], errors='coerce')

# %%
max_base_pay = df2['BasePay'].max()
print("Maximum BasePay:", max_base_pay)
# Out:
# Maximum BasePay: 319275.01

# %% [markdown]
# averge base pay of all employee per year

# %%
df2['BasePay'].describe() # this doesnt give data per year this is giving the collective data
# Out:
# count    148045.000000
# mean      66325.448840
# std       42764.635495
# min        -166.010000
# 25%       33588.200000
# 50%       65007.450000
# 75%       94691.050000
# max      319275.010000
# Name: BasePay, dtype: float64

# %% [markdown]
# to get the collective data we need to use the groupby function

# %%
df4 = data 
df4.groupby('Year')['BasePay'].mean()
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %% [markdown]
# find average base pay of all employee per job title

# %%
df2.groupby('JobTitle')['BasePay'].mean()
# Out:
# JobTitle
# ACCOUNT CLERK                                     43300.806506
# ACCOUNTANT                                        46643.172000
# ACCOUNTANT INTERN                                 28732.663958
# ACPO,JuvP, Juv Prob (SFERS)                       62290.780000
# ACUPUNCTURIST                                     66374.400000
#                                                       ...
# X-RAY LABORATORY AIDE                             47664.773077
# X-Ray Laboratory Aide                             46086.387100
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS    52609.910000
# Youth Comm Advisor                                39077.957500
# ZOO CURATOR                                       43148.000000
# Name: BasePay, Length: 2159, dtype: float64

# %% [markdown]
# find average base pay of employee having job title of accountant

# %%
a = df4[df4['JobTitle'] == 'ACCOUNTANT']['BasePay']

# %%
a.mean()
# Out:
# 46643.172

# %% [markdown]
# find the five most common job in the data set

# %%
df2['JobTitle'].value_counts().head()
# Out:
# JobTitle
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: count, dtype: int64
